# %%
class Details:
    record = {}
    def __init__(self,name,height):
        self.name = name
        self.height = height
        Details.record[name]=self.height
class Record(Details):
    def addRecord():
        name= input("Enter Name of Candidate\n")
        height = input("Enter Height in cm\n")
        if height.isnumeric()==True and float(height)>50 and len(name)>3:
            record = Details(name , float(height))
            print("Details added successfully\n")
        else:
            print("Please Enter Correct Details\n")
    def convert_Height_in_Inch():       
        name= input("Enter Name of Candidate\n")
        if name in Details.record:
            print((0.393701 * Details.record[name]), "inches\n")
        else:
            print("No Candidate found\n")
    def search_By_Name():
        name= input("Enter Name of Candidate\n")
        if name in Details.record:
            print(Details.record[name],"cm\n")
        else:
            print("No Candidate found\n")
    def all_cand_info():
        print(Details.record, "\n")
    def remove_Cand_info():
        name= input("Enter Name of Candidate\n")
        if name in Details.record:
            del Details.record[name]
            print("Details deleted successfully\n")
        else:
            print("No Candidate found\n")
    def modify_height():
        name= input("Enter Name of Candidate to modify\n")
        height = input("Enter New Height in cm\n")
        if name in Details.record and height.isnumeric()==True and float(height)>50:
            Details.record[name]=float(height)
            print("Data Correction Successed")
        else:
            print("No record found")
while True:
    info1=Details("Purnima",150 )
    info2=Details("Sakshi",168 )
    info3=Details("Yatin",178 )
    info4=Details("Irfan",172 )
    info5=Details("Nikita",165 )
    print("1. for add Candidate info\n")
    print("2. for convert height into inches\n")
    print("3. for search by name\n")
    print("4. all Candidate info\n")
    print("5. remove candidate info\n")
    print("6. for modify details\n")
    print("7. for Exit\n")
    n = int(input())
    if n==1:
        Record.addRecord()
    elif n==2:
        Record.convert_Height_in_Inch()
    elif n==3:
         Record.search_By_Name()
    elif n==4:
        Record.all_cand_info()
    elif n==5:
        Record.remove_Cand_info()
    elif n==6:
        Record.modify_height()
    elif n==7:
        print("Bye Bye!!\n")
        break
    else:
        print("please Select Correct option\n")
# Out:
# 1. for add Candidate info
#
# 2. for convert height into inches
#
# 3. for search by name
#
# 4. all Candidate info
#
# 5. remove candidate info
#
# 6. for modify details
#
# 7. for Exit
#
# 1
# Enter Name of Candidate
# rahul
# Enter Height in cm
# 134
# Details added successfully
#
# 1. for add Candidate info
#
# 2. for convert height into inches
#
# 3. for search by name
#
# 4. all Candidate info
#
# 5. remove candidate info
#
# 6. for modify details
#
# 7. for Exit
#
# 6
# Enter Name of Candidate to modify
# rahul
# Enter New Height in cm
# 156
# 1. for add Candidate info
#
# 2. for convert height into inches
#
# 3. for search by name
#
# 4. all Candidate info
#
# 5. remove candidate info
#
# 6. for modify details
#
# 7. for Exit
#
# 4
# {'Purnima': 150, 'Sakshi': 168, 'Yatin': 178, 'Irfan': 172, 'Nikita': 165, 'rahul': 156}
#
# 1. for add Candidate info
#
# 2. for convert height into inches
#
# 3. for search by name
#
# 4. all Candidate info
#
# 5. remove candidate info
#
# ...
